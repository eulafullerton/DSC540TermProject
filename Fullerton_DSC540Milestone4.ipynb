# %% [markdown]
# # Milestone 4
# **Name:** Eula Fullerton
# **Due Date:** Nov 3, 2024
# **Class:** DSC540-T302 Data Preparation
# **Professor:** Professor Williams

# %% [markdown]
# ## Connecting to an API/Pulling in the Data and Cleaning/Formatting
#
#
# Perform at least 5 data transformation and/or cleansing steps to your API data. The below examples are not required - they are just potential transformations you could do. If your data doesn't work for these scenarios, complete different transformations. You can do the same transformation multiple times if needed to clean your data. The goal is a clean dataset at the end of the milestone. As a reminder - you cannot export your API data to CSV to work with it, you must do all the work directly against the API/JSON source.

# %% [markdown]
# Examples:
# - Replace Headers
# - Format data into a more readable format
# - Identify outliers and bad data
# - Find duplicates
# - Fix casing or inconsistent values
# - Conduct Fuzzy Matching
# - Make sure you clearly number and label each transformation step (Step #1, Step #2, etc.) in your code and describe what it is doing in 1-2 sentences.

# %% [markdown]
# Each transformation should:
# - be labeled with description or what it is doing.
# - Human readable dataset after all transformations should be printed at the end of your notebook.
# - 1 paragraph of the ethical implications of data wrangling specific to your datasource and the steps you completed answering the following questions:
# - What changes were made to the data?
# - Are there any legal or regulatory guidelines for your data or project topic?
# - What risks could be created based on the transformations done?
# - Did you make any assumptions in cleaning/transforming the data?
# - How was your data sourced / verified for credibility?
# - Was your data acquired in an ethical way?
# - How would you mitigate any of the ethical implications you have identified?

# %% [markdown]
# ## About Open FDA App
#
# openFDA is an Elasticsearch-based API that serves public FDA data about nouns like drugs, devices, and foods.
#
# Each of these nouns has one or more categories, which serve unique data-such as data about recall enforcement reports, or about adverse events. Every query to the API must go through one endpoint for one kind of data.
#
# Not all data in openFDA has been validated for clinical or production use. And because openFDA only serves publicly available data, it does not contain data with Personally Identifiable Information about patients or other sensitive information.
#
# "API" is an acronym for Application Programming Interface. An API call is any request sent to the API. Requests are typically sent to the API in one of two ways: 1. Manually using a web browser (such as navigating to the URL https://api.fda.gov/drug/label.json) or 2. Programmatically sending the request via executing code that sends the API call and processes the response. Continue reading this documentation for more details on how to compose an API call for openFDA specifically.
#
# The API returns individual results as JSON by default. The JSON object has two sections:
#
# meta: Metadata about the query, including a disclaimer, link to data license, last-updated date, and total matching records, if applicable.
#
# results: An array of matching results, dependent on which endpoint was queried.

# %% [markdown]
# ## Step 1: Connect to API

# %%
import requests

# API key
api_key = "LEwHbldDDJhHhHq3riKDswyLbOKo6HsRXHXG3NoL"

# Base URL
base_url = "https://api.fda.gov/drug/event.json"

# Drugs to search for with pregnancy relevance
drugs = [
    "Insulin", "Labetalol", "Magnesium sulfate", "Progesterone",
    "Ceftriaxone", "Penicillin G", "Azithromycin", "Lamivudine", "Nicotine"
]

# Dictionary to store results for each drug
drug_results = {}

# Loop through each drug and fetch pregnancy-relevant data
for drug in drugs:
    # Include pregnancy-related search terms with the drug name
    search_query = f'patient.drug.medicinalproduct:"{drug}" AND (patient.reaction.reactionmeddrapt:"pregnancy" OR patient.reaction.reactionmeddrapt:"pregnant" OR patient.reaction.reactionmeddrapt:"fetal")'
    url = f"{base_url}?api_key={api_key}&search={search_query}&limit=5"  # limit results for simplicity
    
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        drug_results[drug] = data if data.get("results") else None
        print(f"Pregnancy-related results found for {drug}")
    else:
        drug_results[drug] = None
        print(f"No results found for {drug}: {response.status_code} - {response.text}")

# write results into file to view
import json
with open("pregnancy_related_drug_results.json", "w") as file:
    json.dump(drug_results, file)
# Out:
# Pregnancy-related results found for Insulin
# Pregnancy-related results found for Labetalol
# Pregnancy-related results found for Magnesium sulfate
# Pregnancy-related results found for Progesterone
# Pregnancy-related results found for Ceftriaxone
# Pregnancy-related results found for Penicillin G
# Pregnancy-related results found for Azithromycin
# Pregnancy-related results found for Lamivudine
# Pregnancy-related results found for Nicotine

# %% [markdown]
# ## Step 1: Load and Inspect Data

# %% [markdown]
# Load JSON file and inspect the structure to understand relevant fields

# %%
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in c:\users\samue\anaconda3\lib\site-packages (0.18.0)

# %%
import json
import pandas as pd
from fuzzywuzzy import process  # For fuzzy matching
from IPython.display import display  # For displaying DataFrames in Jupyter Notebook

# Load JSON data
with open('pregnancy_related_drug_results.json', 'r') as file:
    data = json.load(file)

# Initial inspection of the structure
data.keys()
# Out:
# dict_keys(['Insulin', 'Labetalol', 'Magnesium sulfate', 'Progesterone', 'Ceftriaxone', 'Penicillin G', 'Azithromycin', 'Lamivudine', 'Nicotine'])

# %% [markdown]
# ## Step 2: Flatten Data Structure

# %% [markdown]
# Extract nested fields such as patient, reaction, and drug into a flat structure to make it easier to analyze in a dataframe.

# %%
# Flatten JSON structure for DataFrame creation
reports = []
for drug, entries in data.items():
    if entries and "results" in entries:
        for result in entries["results"]:
            report = {
                "report_id": result.get("safetyreportid"),
                "patient_age": result.get("patient", {}).get("patientonsetage"),
                "patient_sex": result.get("patient", {}).get("patientsex"),
                "patient_weight": result.get("patient", {}).get("patientweight"),
                "reaction_event": [reaction.get("reactionmeddrapt") for reaction in result.get("patient", {}).get("reaction", [])],
                "medicinal_product": [drug_info.get("medicinalproduct") for drug_info in result.get("patient", {}).get("drug", [])],
                "drug_indication": [drug_info.get("drugindication") for drug_info in result.get("patient", {}).get("drug", [])],
                "seriousness_congenital_anomaly": result.get("seriousnesscongenitalanomali")
            }
            reports.append(report)

# Create DataFrame
df = pd.DataFrame(reports)
display(df.head())
# Out:
#   report_id patient_age patient_sex patient_weight  \
# 0  10009044           1           1              4
# 1  10016807        None           0           None
# 2  10019262        None           2           2.54
# 3  10023714          35           2             68
# 4  10038823           0           2            3.6
#
#                                       reaction_event  \
# 0  [Congenital hydronephrosis, Ureteric stenosis,...
# 1  [Foetal death, Foetal heart rate deceleration ...
# 2  [Foetal exposure during pregnancy, Multiple co...
# 3  [No therapeutic response, Ectopic pregnancy, E...
# 4  [Ventricular septal defect, Atrial septal defe...
#
#                                    medicinal_product  \
# 0  [METOPROLOL (UNKNOWN), BISOPROLOL, INSULIN, FO...
# 1  [HYDRALAZINE, METHYLDOPA, TELMISARTAN, AMLODIP...
# 2            [EFFEXOR, ZYPREXA, LEVOTHYROX, INSULIN]
# 3              [INSULIN GLARGINE, SOLOSTAR, HUMALOG]
# 4  [COMBIVIR, KALETRA, METFORMIN, INSULIN, NEXIUM...
#
#                                      drug_indication  \
# 0  [HYPERTENSION, HYPERTENSION, GESTATIONAL DIABE...
# 1  [None, None, None, None, None, None, None, Non...
# 2           [None, None, None, GESTATIONAL DIABETES]
# 3                    [DIABETES MELLITUS, None, None]
# 4  [HIV INFECTION, HIV INFECTION, DIABETES MELLIT...
#
#   seriousness_congenital_anomaly
# 0                              1
# 1                           None
# 2                              1
# 3                           None
# 4                              1

# %% [markdown]
# ## Step 3: Standaradize Column Names

# %% [markdown]
# Standardize the column names and rename them all to lowercase and replace spaces with underscoress for consistency

# %%
# Standardize column names
df.columns = [col.lower().replace(" ", "_") for col in df.columns]
display(df.head())
# Out:
#   report_id patient_age patient_sex patient_weight  \
# 0  10009044           1           1              4
# 1  10016807        None           0           None
# 2  10019262        None           2           2.54
# 3  10023714          35           2             68
# 4  10038823           0           2            3.6
#
#                                       reaction_event  \
# 0  [Congenital hydronephrosis, Ureteric stenosis,...
# 1  [Foetal death, Foetal heart rate deceleration ...
# 2  [Foetal exposure during pregnancy, Multiple co...
# 3  [No therapeutic response, Ectopic pregnancy, E...
# 4  [Ventricular septal defect, Atrial septal defe...
#
#                                    medicinal_product  \
# 0  [METOPROLOL (UNKNOWN), BISOPROLOL, INSULIN, FO...
# 1  [HYDRALAZINE, METHYLDOPA, TELMISARTAN, AMLODIP...
# 2            [EFFEXOR, ZYPREXA, LEVOTHYROX, INSULIN]
# 3              [INSULIN GLARGINE, SOLOSTAR, HUMALOG]
# 4  [COMBIVIR, KALETRA, METFORMIN, INSULIN, NEXIUM...
#
#                                      drug_indication  \
# 0  [HYPERTENSION, HYPERTENSION, GESTATIONAL DIABE...
# 1  [None, None, None, None, None, None, None, Non...
# 2           [None, None, None, GESTATIONAL DIABETES]
# 3                    [DIABETES MELLITUS, None, None]
# 4  [HIV INFECTION, HIV INFECTION, DIABETES MELLIT...
#
#   seriousness_congenital_anomaly
# 0                              1
# 1                           None
# 2                              1
# 3                           None
# 4                              1

# %% [markdown]
# ## Step 4: Flatten Lists in Columns

# %%
# Flatten lists in specified columns, handling None values
df['reaction_event'] = df['reaction_event'].apply(lambda x: ', '.join(filter(None, x)) if isinstance(x, list) else x)
df['medicinal_product'] = df['medicinal_product'].apply(lambda x: ', '.join(filter(None, x)) if isinstance(x, list) else x)
df['drug_indication'] = df['drug_indication'].apply(lambda x: ', '.join(filter(None, x)) if isinstance(x, list) else x)

# Display the modified DataFrame
display(df.head())
# Out:
#   report_id patient_age patient_sex patient_weight  \
# 0  10009044           1           1              4
# 1  10016807        None           0           None
# 2  10019262        None           2           2.54
# 3  10023714          35           2             68
# 4  10038823           0           2            3.6
#
#                                       reaction_event  \
# 0  Congenital hydronephrosis, Ureteric stenosis, ...
# 1  Foetal death, Foetal heart rate deceleration a...
# 2  Foetal exposure during pregnancy, Multiple con...
# 3  No therapeutic response, Ectopic pregnancy, Ex...
# 4  Ventricular septal defect, Atrial septal defec...
#
#                                    medicinal_product  \
# 0  METOPROLOL (UNKNOWN), BISOPROLOL, INSULIN, FOL...
# 1  HYDRALAZINE, METHYLDOPA, TELMISARTAN, AMLODIPI...
# 2              EFFEXOR, ZYPREXA, LEVOTHYROX, INSULIN
# 3                INSULIN GLARGINE, SOLOSTAR, HUMALOG
# 4  COMBIVIR, KALETRA, METFORMIN, INSULIN, NEXIUM,...
#
#                                      drug_indication  \
# 0  HYPERTENSION, HYPERTENSION, GESTATIONAL DIABET...
# 1
# 2                               GESTATIONAL DIABETES
# 3                                  DIABETES MELLITUS
# 4  HIV INFECTION, HIV INFECTION, DIABETES MELLITU...
#
#   seriousness_congenital_anomaly
# 0                              1
# 1                           None
# 2                              1
# 3                           None
# 4                              1

# %% [markdown]
# ## Step 5: Remove duplicate reports

# %% [markdown]
# Duplicates were removed from the report

# %%
# Identify duplicate entries based on 'report_id', excluding the first occurrence
duplicates = df[df.duplicated(subset=['report_id'], keep='first')]

# Display the duplicates
display(duplicates)
# Out:
#    report_id patient_age patient_sex patient_weight  \
# 38  10014483           8        None           None
#
#                                        reaction_event  \
# 38  Anaemia, Toxicity to various agents, Foetal ex...
#
#                                     medicinal_product  \
# 38  ISENTRESS, ISENTRESS, ISENTRESS, ABACAVIR, ABA...
#
#                                       drug_indication  \
# 38  HIV infection, Product used for unknown indica...
#
#    seriousness_congenital_anomaly
# 38                              2

# %%
# Remove duplicate entries based on 'report_id'
df.drop_duplicates(subset=['report_id'], inplace=True)
display(df.head())
# Out:
#   report_id patient_age patient_sex patient_weight  \
# 0  10009044           1           1              4
# 1  10016807        None           0           None
# 2  10019262        None           2           2.54
# 3  10023714          35           2             68
# 4  10038823           0           2            3.6
#
#                                       reaction_event  \
# 0  Congenital hydronephrosis, Ureteric stenosis, ...
# 1  Foetal death, Foetal heart rate deceleration a...
# 2  Foetal exposure during pregnancy, Multiple con...
# 3  No therapeutic response, Ectopic pregnancy, Ex...
# 4  Ventricular septal defect, Atrial septal defec...
#
#                                    medicinal_product  \
# 0  METOPROLOL (UNKNOWN), BISOPROLOL, INSULIN, FOL...
# 1  HYDRALAZINE, METHYLDOPA, TELMISARTAN, AMLODIPI...
# 2              EFFEXOR, ZYPREXA, LEVOTHYROX, INSULIN
# 3                INSULIN GLARGINE, SOLOSTAR, HUMALOG
# 4  COMBIVIR, KALETRA, METFORMIN, INSULIN, NEXIUM,...
#
#                                      drug_indication  \
# 0  HYPERTENSION, HYPERTENSION, GESTATIONAL DIABET...
# 1
# 2                               GESTATIONAL DIABETES
# 3                                  DIABETES MELLITUS
# 4  HIV INFECTION, HIV INFECTION, DIABETES MELLITU...
#
#   seriousness_congenital_anomaly
# 0                              1
# 1                           None
# 2                              1
# 3                           None
# 4                              1

# %% [markdown]
# ## Step 7: Standardize Text Casing

# %% [markdown]
# convert medicinal_product and reaction event columns to lowercase to ensure consistent casing

# %%
# Standardize text casing
df['medicinal_product'] = df['medicinal_product'].str.lower()
df['reaction_event'] = df['reaction_event'].str.lower()
display(df[['medicinal_product', 'reaction_event']].head())
# Out:
#                                    medicinal_product  \
# 0  metoprolol (unknown), bisoprolol, insulin, fol...
# 1  hydralazine, methyldopa, telmisartan, amlodipi...
# 2              effexor, zyprexa, levothyrox, insulin
# 3                insulin glargine, solostar, humalog
# 4  combivir, kaletra, metformin, insulin, nexium,...
#
#                                       reaction_event
# 0  congenital hydronephrosis, ureteric stenosis, ...
# 1  foetal death, foetal heart rate deceleration a...
# 2  foetal exposure during pregnancy, multiple con...
# 3  no therapeutic response, ectopic pregnancy, ex...
# 4  ventricular septal defect, atrial septal defec...

# %% [markdown]
# ## Step 8: Create a New Column for target drug

# %% [markdown]
# Separate the target drugs below from the others in the medicinal product column:
# ["insulin", "labetalol", "magnesium sulfate", "progesterone", "ceftriaxone", "penicillin g", "azithromycin", "lamivudine", "nicotine"]

# %%
# Define the target drugs (case-insensitive)
target_drugs = ["insulin", "labetalol", "magnesium sulfate", "progesterone", 
                "ceftriaxone", "penicillin g", "azithromycin", "lamivudine", "nicotine"]

# Function to separate target drugs from other products
def separate_drugs(row):
    products = [prod.strip().lower() for prod in row['medicinal_product'].split(',')]
    target = [prod for prod in products if any(td in prod for td in target_drugs)]
    other = [prod for prod in products if prod not in target]
    return pd.Series([', '.join(target), ', '.join(other)])

# Apply the function to split target and other drugs into separate columns
df[['target_medicinal_product', 'other_medicinal_product']] = df.apply(separate_drugs, axis=1)

# Display the DataFrame with separated columns
display(df[['medicinal_product', 'target_medicinal_product', 'other_medicinal_product', 'reaction_event']])
# Out:
#                                     medicinal_product  \
# 0   metoprolol (unknown), bisoprolol, insulin, fol...
# 1   hydralazine, methyldopa, telmisartan, amlodipi...
# 2               effexor, zyprexa, levothyrox, insulin
# 3                 insulin glargine, solostar, humalog
# 4   combivir, kaletra, metformin, insulin, nexium,...
# 5   mycophenolate mofetil, calcitriol, azathioprin...
# 6        nifedipine, nifedipine, labetalol, labetalol
# 7                   nifedipine, nifedipine, labetalol
# 8   hydrochlorothiazide., triamcinolone, labetalol...
# 9   oxytocin, salbutamol, fluticasone, calcium, la...
# 10  magnesium sulfate, heparin, ritodrine hydrochl...
# 11         uteron, magnesium sulfate., betamethasone.
# 12  uteron, betamethasone., uteron, magnesium sulf...
# 13  uteron, uteron, betamethasone., magnesium sulf...
# 14  uteron, uteron, magnesium sulfate., betamethas...
# 15  progesterone., glucophage, eltroxin, glucophag...
# 16  armour thyroid, procardia, lovenox, aspirin, p...
# 17       lovenox, estradiol, progesterone, folic acid
# 18      bravelle, decapeptyl /00957902/, progesterone
# 19  acetylsalicylic acid({=100 mg), progesterone (...
# 20                         ceftriaxone, metronidazole
# 21                         ceftriaxone, metronidazole
# 22            ceftriaxone, metronidazole, amoxicillin
# 23            ceftriaxone, metronidazole, amoxicillin
# 24  ceftriaxone, clarithromycin, amoxicillin+clavu...
# 25  ranitidine, penicillin g, entonox, paracetamol...
# 26              penicillin g potassium injection, usp
# 27              penicillin g potassium injection, usp
# 28  penicillin g potassium injection, usp, penicil...
# 29  augmentin, effexor, venlafaxine hydrochloride ...
# 30  isentress, isentress, isentress, abacavir, aba...
# 31  effexor, amox-clav, effexor, venlafaxine hcl, ...
# 32  venlafaxine, nitrofur mac, metronidazole., zan...
# 33  ceftriaxone injection, usp (in dextrose), zosy...
# 34  wellbutrin, wellbutrin xl, clarinex, naproxen....
# 35                  abacavir, lamivudine-hiv, kaletra
# 36                  abacavir, lamivudine-hiv, kaletra
# 37                      kaletra, lamivudine, abacavir
# 39  lamivudine and zidovudine, prezista, lexiva, z...
# 40                    buprenorphine generic, nicotine
# 41  suboxone film, alcohol, nicotine, prenatal vit...
# 42                     suboxone 8 mg, nicotine (none)
# 43         suboxone, subutex 8 mg, nicotine, vitamins
# 44  suboxone 8 mg, buprenorphine 8 mg (none), unsp...
#
#                              target_medicinal_product  \
# 0                                             insulin
# 1                                             insulin
# 2                                             insulin
# 3                                    insulin glargine
# 4                                             insulin
# 5                                           labetalol
# 6                                labetalol, labetalol
# 7                                           labetalol
# 8                                           labetalol
# 9                                           labetalol
# 10                                  magnesium sulfate
# 11                                 magnesium sulfate.
# 12                                 magnesium sulfate.
# 13                                 magnesium sulfate.
# 14                                 magnesium sulfate.
# 15                                      progesterone.
# 16                                       progesterone
# 17                                       progesterone
# 18                                       progesterone
# 19                            progesterone (solution)
# 20                                        ceftriaxone
# 21                                        ceftriaxone
# 22                                        ceftriaxone
# 23                                        ceftriaxone
# 24                                        ceftriaxone
# 25                                       penicillin g
# 26                   penicillin g potassium injection
# 27                   penicillin g potassium injection
# 28  penicillin g potassium injection, penicillin g...
# 29                                       penicillin g
# 30  azithromycin, azithromycin, lamivudine, lamivu...
# 31                                       azithromycin
# 32                                       azithromycin
# 33                ceftriaxone injection, azithromycin
# 34                                       azithromycin
# 35                                     lamivudine-hiv
# 36                                     lamivudine-hiv
# 37                                         lamivudine
# 39                          lamivudine and zidovudine
# 40                                           nicotine
# 41                                           nicotine
# 42                                    nicotine (none)
# 43                                           nicotine
# 44                                           nicotine
#
#                               other_medicinal_product  \
# 0   metoprolol (unknown), bisoprolol, folio, dopeg...
# 1   hydralazine, methyldopa, telmisartan, amlodipi...
# 2                        effexor, zyprexa, levothyrox
# 3                                   solostar, humalog
# 4   combivir, kaletra, metformin, nexium, prenatal...
# 5   mycophenolate mofetil, calcitriol, azathioprin...
# 6                              nifedipine, nifedipine
# 7                              nifedipine, nifedipine
# 8   hydrochlorothiazide., triamcinolone, tylenol, ...
# 9   oxytocin, salbutamol, fluticasone, calcium, fe...
# 10                   heparin, ritodrine hydrochloride
# 11                             uteron, betamethasone.
# 12                     uteron, betamethasone., uteron
# 13                     uteron, uteron, betamethasone.
# 14                     uteron, uteron, betamethasone.
# 15          glucophage, eltroxin, glucophage, clexane
# 16  armour thyroid, procardia, lovenox, aspirin, c...
# 17                     lovenox, estradiol, folic acid
# 18                    bravelle, decapeptyl /00957902/
# 19  acetylsalicylic acid({=100 mg), procardia, lov...
# 20                                      metronidazole
# 21                                      metronidazole
# 22                         metronidazole, amoxicillin
# 23                         metronidazole, amoxicillin
# 24  clarithromycin, amoxicillin+clavulanate, cefme...
# 25  ranitidine, entonox, paracetamol, piriton, lev...
# 26                                                usp
# 27                                                usp
# 28                                           usp, usp
# 29  augmentin, effexor, venlafaxine hydrochloride ...
# 30  isentress, isentress, isentress, abacavir, aba...
# 31  effexor, amox-clav, effexor, venlafaxine hcl, ...
# 32  venlafaxine, nitrofur mac, metronidazole., zan...
# 33                           usp (in dextrose), zosyn
# 34  wellbutrin, wellbutrin xl, clarinex, naproxen....
# 35                                  abacavir, kaletra
# 36                                  abacavir, kaletra
# 37                                  kaletra, abacavir
# 39       prezista, lexiva, zidovudine, norvir, viread
# 40                              buprenorphine generic
# 41  suboxone film, alcohol, prenatal vitamins, zol...
# 42                                      suboxone 8 mg
# 43                   suboxone, subutex 8 mg, vitamins
# 44  suboxone 8 mg, buprenorphine 8 mg (none), unsp...
#
#                                        reaction_event
# 0   congenital hydronephrosis, ureteric stenosis, ...
# 1   foetal death, foetal heart rate deceleration a...
# 2   foetal exposure during pregnancy, multiple con...
# 3   no therapeutic response, ectopic pregnancy, ex...
# 4   ventricular septal defect, atrial septal defec...
# 5    maternal exposure during pregnancy, foetal death
# 6   neonatal respiratory distress syndrome, jaundi...
# 7   hypertension, premature delivery, exposure dur...
# 8   injury, premature delivery, device breakage, u...
# 9   hypertension, renal failure chronic, condition...
# 10  premature baby, apgar score low, acidosis, foe...
# 11  maternal exposure during pregnancy, pulmonary ...
# 12  maternal exposure during pregnancy, pulmonary ...
# 13  pulmonary oedema, maternal exposure during pre...
# 14  maternal exposure during pregnancy, pulmonary ...
# 15  abortion spontaneous, maternal exposure during...
# 16  oligohydramnios, foetal growth restriction, ex...
# 17              thrombosis, exposure during pregnancy
# 18                                  ectopic pregnancy
# 19         oligohydramnios, exposure during pregnancy
# 20  meconium stain, amniotic cavity infection, mat...
# 21  foetal death, abortion late, amniotic cavity i...
# 22  foetal distress syndrome, intraventricular hae...
# 23  meconium stain, amniotic cavity infection, mat...
# 24  pyelonephritis, maternal exposure during pregn...
# 25  angioedema, enlarged uvula, live birth, exposu...
# 26     exposure during pregnancy, injection site pain
# 27      exposure during pregnancy, infusion site pain
# 28  burning sensation, exposure during pregnancy, ...
# 29  double outlet right ventricle, pulmonary arter...
# 30  anaemia, toxicity to various agents, foetal ex...
# 31    maternal exposure during pregnancy, anencephaly
# 32  congenital anomaly, meningomyelocele, talipes,...
# 33  vaginal haemorrhage, abdominal pain lower, exp...
# 34  maternal exposure during pregnancy, patent duc...
# 35  dialysis, blood pressure inadequately controll...
# 36  acute hepatic failure, renal failure acute, re...
# 37  premature baby, acute hepatic failure, renal f...
# 39     micrognathia, foetal exposure during pregnancy
# 40  wrong technique in drug usage process, materna...
# 41  maternal exposure during pregnancy, alcohol ab...
# 42  foetal exposure during pregnancy, drug withdra...
# 43      selective abortion, exposure during pregnancy
# 44  foetal exposure during pregnancy, drug withdra...

# %%
# Remove the original medicinal_product column afer separating the target and other products
df.drop(columns=['medicinal_product'], inplace=True)

# Display the updated DataFrame
display(df[['target_medicinal_product', 'other_medicinal_product', 'reaction_event']])
# Out:
#                              target_medicinal_product  \
# 0                                             insulin
# 1                                             insulin
# 2                                             insulin
# 3                                    insulin glargine
# 4                                             insulin
# 5                                           labetalol
# 6                                labetalol, labetalol
# 7                                           labetalol
# 8                                           labetalol
# 9                                           labetalol
# 10                                  magnesium sulfate
# 11                                 magnesium sulfate.
# 12                                 magnesium sulfate.
# 13                                 magnesium sulfate.
# 14                                 magnesium sulfate.
# 15                                      progesterone.
# 16                                       progesterone
# 17                                       progesterone
# 18                                       progesterone
# 19                            progesterone (solution)
# 20                                        ceftriaxone
# 21                                        ceftriaxone
# 22                                        ceftriaxone
# 23                                        ceftriaxone
# 24                                        ceftriaxone
# 25                                       penicillin g
# 26                   penicillin g potassium injection
# 27                   penicillin g potassium injection
# 28  penicillin g potassium injection, penicillin g...
# 29                                       penicillin g
# 30  azithromycin, azithromycin, lamivudine, lamivu...
# 31                                       azithromycin
# 32                                       azithromycin
# 33                ceftriaxone injection, azithromycin
# 34                                       azithromycin
# 35                                     lamivudine-hiv
# 36                                     lamivudine-hiv
# 37                                         lamivudine
# 39                          lamivudine and zidovudine
# 40                                           nicotine
# 41                                           nicotine
# 42                                    nicotine (none)
# 43                                           nicotine
# 44                                           nicotine
#
#                               other_medicinal_product  \
# 0   metoprolol (unknown), bisoprolol, folio, dopeg...
# 1   hydralazine, methyldopa, telmisartan, amlodipi...
# 2                        effexor, zyprexa, levothyrox
# 3                                   solostar, humalog
# 4   combivir, kaletra, metformin, nexium, prenatal...
# 5   mycophenolate mofetil, calcitriol, azathioprin...
# 6                              nifedipine, nifedipine
# 7                              nifedipine, nifedipine
# 8   hydrochlorothiazide., triamcinolone, tylenol, ...
# 9   oxytocin, salbutamol, fluticasone, calcium, fe...
# 10                   heparin, ritodrine hydrochloride
# 11                             uteron, betamethasone.
# 12                     uteron, betamethasone., uteron
# 13                     uteron, uteron, betamethasone.
# 14                     uteron, uteron, betamethasone.
# 15          glucophage, eltroxin, glucophage, clexane
# 16  armour thyroid, procardia, lovenox, aspirin, c...
# 17                     lovenox, estradiol, folic acid
# 18                    bravelle, decapeptyl /00957902/
# 19  acetylsalicylic acid({=100 mg), procardia, lov...
# 20                                      metronidazole
# 21                                      metronidazole
# 22                         metronidazole, amoxicillin
# 23                         metronidazole, amoxicillin
# 24  clarithromycin, amoxicillin+clavulanate, cefme...
# 25  ranitidine, entonox, paracetamol, piriton, lev...
# 26                                                usp
# 27                                                usp
# 28                                           usp, usp
# 29  augmentin, effexor, venlafaxine hydrochloride ...
# 30  isentress, isentress, isentress, abacavir, aba...
# 31  effexor, amox-clav, effexor, venlafaxine hcl, ...
# 32  venlafaxine, nitrofur mac, metronidazole., zan...
# 33                           usp (in dextrose), zosyn
# 34  wellbutrin, wellbutrin xl, clarinex, naproxen....
# 35                                  abacavir, kaletra
# 36                                  abacavir, kaletra
# 37                                  kaletra, abacavir
# 39       prezista, lexiva, zidovudine, norvir, viread
# 40                              buprenorphine generic
# 41  suboxone film, alcohol, prenatal vitamins, zol...
# 42                                      suboxone 8 mg
# 43                   suboxone, subutex 8 mg, vitamins
# 44  suboxone 8 mg, buprenorphine 8 mg (none), unsp...
#
#                                        reaction_event
# 0   congenital hydronephrosis, ureteric stenosis, ...
# 1   foetal death, foetal heart rate deceleration a...
# 2   foetal exposure during pregnancy, multiple con...
# 3   no therapeutic response, ectopic pregnancy, ex...
# 4   ventricular septal defect, atrial septal defec...
# 5    maternal exposure during pregnancy, foetal death
# 6   neonatal respiratory distress syndrome, jaundi...
# 7   hypertension, premature delivery, exposure dur...
# 8   injury, premature delivery, device breakage, u...
# 9   hypertension, renal failure chronic, condition...
# 10  premature baby, apgar score low, acidosis, foe...
# 11  maternal exposure during pregnancy, pulmonary ...
# 12  maternal exposure during pregnancy, pulmonary ...
# 13  pulmonary oedema, maternal exposure during pre...
# 14  maternal exposure during pregnancy, pulmonary ...
# 15  abortion spontaneous, maternal exposure during...
# 16  oligohydramnios, foetal growth restriction, ex...
# 17              thrombosis, exposure during pregnancy
# 18                                  ectopic pregnancy
# 19         oligohydramnios, exposure during pregnancy
# 20  meconium stain, amniotic cavity infection, mat...
# 21  foetal death, abortion late, amniotic cavity i...
# 22  foetal distress syndrome, intraventricular hae...
# 23  meconium stain, amniotic cavity infection, mat...
# 24  pyelonephritis, maternal exposure during pregn...
# 25  angioedema, enlarged uvula, live birth, exposu...
# 26     exposure during pregnancy, injection site pain
# 27      exposure during pregnancy, infusion site pain
# 28  burning sensation, exposure during pregnancy, ...
# 29  double outlet right ventricle, pulmonary arter...
# 30  anaemia, toxicity to various agents, foetal ex...
# 31    maternal exposure during pregnancy, anencephaly
# 32  congenital anomaly, meningomyelocele, talipes,...
# 33  vaginal haemorrhage, abdominal pain lower, exp...
# 34  maternal exposure during pregnancy, patent duc...
# 35  dialysis, blood pressure inadequately controll...
# 36  acute hepatic failure, renal failure acute, re...
# 37  premature baby, acute hepatic failure, renal f...
# 39     micrognathia, foetal exposure during pregnancy
# 40  wrong technique in drug usage process, materna...
# 41  maternal exposure during pregnancy, alcohol ab...
# 42  foetal exposure during pregnancy, drug withdra...
# 43      selective abortion, exposure during pregnancy
# 44  foetal exposure during pregnancy, drug withdra...

# %% [markdown]
# ## Step 9: Create a new column for target pregnancy reactions

# %% [markdown]
# Separate pregnancy related reaction evens and other reaction events

# %%
# Define pregnancy-related keywords
pregnancy_keywords = ["pregnancy", "premature delivery", "foetal", "ectopic", "exposure during pregnancy"]

# Function to separate pregnancy-related reactions from other reactions
def separate_reactions(row):
    reactions = [reaction.strip().lower() for reaction in row['reaction_event'].split(',')]
    pregnancy_reactions = [reaction for reaction in reactions if any(keyword in reaction for keyword in pregnancy_keywords)]
    other_reactions = [reaction for reaction in reactions if reaction not in pregnancy_reactions]
    return pd.Series([', '.join(pregnancy_reactions), ', '.join(other_reactions)])

# Apply the function to split reactions into separate columns
df[['pregnancy_reaction_event', 'other_reaction_event']] = df.apply(separate_reactions, axis=1)

# Drop the original 'reaction_event' column 
df.drop(columns=['reaction_event'], inplace=True)

# Display the updated DataFrame
display(df[['target_medicinal_product', 'other_medicinal_product', 'pregnancy_reaction_event', 'other_reaction_event']])
# Out:
#                              target_medicinal_product  \
# 0                                             insulin
# 1                                             insulin
# 2                                             insulin
# 3                                    insulin glargine
# 4                                             insulin
# 5                                           labetalol
# 6                                labetalol, labetalol
# 7                                           labetalol
# 8                                           labetalol
# 9                                           labetalol
# 10                                  magnesium sulfate
# 11                                 magnesium sulfate.
# 12                                 magnesium sulfate.
# 13                                 magnesium sulfate.
# 14                                 magnesium sulfate.
# 15                                      progesterone.
# 16                                       progesterone
# 17                                       progesterone
# 18                                       progesterone
# 19                            progesterone (solution)
# 20                                        ceftriaxone
# 21                                        ceftriaxone
# 22                                        ceftriaxone
# 23                                        ceftriaxone
# 24                                        ceftriaxone
# 25                                       penicillin g
# 26                   penicillin g potassium injection
# 27                   penicillin g potassium injection
# 28  penicillin g potassium injection, penicillin g...
# 29                                       penicillin g
# 30  azithromycin, azithromycin, lamivudine, lamivu...
# 31                                       azithromycin
# 32                                       azithromycin
# 33                ceftriaxone injection, azithromycin
# 34                                       azithromycin
# 35                                     lamivudine-hiv
# 36                                     lamivudine-hiv
# 37                                         lamivudine
# 39                          lamivudine and zidovudine
# 40                                           nicotine
# 41                                           nicotine
# 42                                    nicotine (none)
# 43                                           nicotine
# 44                                           nicotine
#
#                               other_medicinal_product  \
# 0   metoprolol (unknown), bisoprolol, folio, dopeg...
# 1   hydralazine, methyldopa, telmisartan, amlodipi...
# 2                        effexor, zyprexa, levothyrox
# 3                                   solostar, humalog
# 4   combivir, kaletra, metformin, nexium, prenatal...
# 5   mycophenolate mofetil, calcitriol, azathioprin...
# 6                              nifedipine, nifedipine
# 7                              nifedipine, nifedipine
# 8   hydrochlorothiazide., triamcinolone, tylenol, ...
# 9   oxytocin, salbutamol, fluticasone, calcium, fe...
# 10                   heparin, ritodrine hydrochloride
# 11                             uteron, betamethasone.
# 12                     uteron, betamethasone., uteron
# 13                     uteron, uteron, betamethasone.
# 14                     uteron, uteron, betamethasone.
# 15          glucophage, eltroxin, glucophage, clexane
# 16  armour thyroid, procardia, lovenox, aspirin, c...
# 17                     lovenox, estradiol, folic acid
# 18                    bravelle, decapeptyl /00957902/
# 19  acetylsalicylic acid({=100 mg), procardia, lov...
# 20                                      metronidazole
# 21                                      metronidazole
# 22                         metronidazole, amoxicillin
# 23                         metronidazole, amoxicillin
# 24  clarithromycin, amoxicillin+clavulanate, cefme...
# 25  ranitidine, entonox, paracetamol, piriton, lev...
# 26                                                usp
# 27                                                usp
# 28                                           usp, usp
# 29  augmentin, effexor, venlafaxine hydrochloride ...
# 30  isentress, isentress, isentress, abacavir, aba...
# 31  effexor, amox-clav, effexor, venlafaxine hcl, ...
# 32  venlafaxine, nitrofur mac, metronidazole., zan...
# 33                           usp (in dextrose), zosyn
# 34  wellbutrin, wellbutrin xl, clarinex, naproxen....
# 35                                  abacavir, kaletra
# 36                                  abacavir, kaletra
# 37                                  kaletra, abacavir
# 39       prezista, lexiva, zidovudine, norvir, viread
# 40                              buprenorphine generic
# 41  suboxone film, alcohol, prenatal vitamins, zol...
# 42                                      suboxone 8 mg
# 43                   suboxone, subutex 8 mg, vitamins
# 44  suboxone 8 mg, buprenorphine 8 mg (none), unsp...
#
#                              pregnancy_reaction_event  \
# 0                    foetal exposure during pregnancy
# 1   foetal death, foetal heart rate deceleration a...
# 2                    foetal exposure during pregnancy
# 3        ectopic pregnancy, exposure during pregnancy
# 4                    foetal exposure during pregnancy
# 5    maternal exposure during pregnancy, foetal death
# 6                    foetal exposure during pregnancy
# 7       premature delivery, exposure during pregnancy
# 8   premature delivery, pregnancy with contracepti...
# 9                  maternal exposure during pregnancy
# 10                   foetal exposure during pregnancy
# 11                 maternal exposure during pregnancy
# 12                 maternal exposure during pregnancy
# 13                 maternal exposure during pregnancy
# 14                 maternal exposure during pregnancy
# 15                 maternal exposure during pregnancy
# 16  foetal growth restriction, exposure during pre...
# 17                          exposure during pregnancy
# 18                                  ectopic pregnancy
# 19                          exposure during pregnancy
# 20                 maternal exposure during pregnancy
# 21   foetal death, maternal exposure during pregnancy
# 22  foetal distress syndrome, foetal exposure duri...
# 23                 maternal exposure during pregnancy
# 24                 maternal exposure during pregnancy
# 25                          exposure during pregnancy
# 26                          exposure during pregnancy
# 27                          exposure during pregnancy
# 28                          exposure during pregnancy
# 29                   foetal exposure during pregnancy
# 30                   foetal exposure during pregnancy
# 31                 maternal exposure during pregnancy
# 32                 maternal exposure during pregnancy
# 33            exposure during pregnancy, foetal death
# 34  maternal exposure during pregnancy, persistent...
# 35      premature delivery, exposure during pregnancy
# 36                   foetal exposure during pregnancy
# 37  foetal growth restriction, foetal exposure dur...
# 39                   foetal exposure during pregnancy
# 40                 maternal exposure during pregnancy
# 41                 maternal exposure during pregnancy
# 42                   foetal exposure during pregnancy
# 43                          exposure during pregnancy
# 44                   foetal exposure during pregnancy
#
#                                  other_reaction_event
# 0        congenital hydronephrosis, ureteric stenosis
# 1                                      premature baby
# 2                   multiple congenital abnormalities
# 3                             no therapeutic response
# 4   ventricular septal defect, atrial septal defec...
# 5
# 6   neonatal respiratory distress syndrome, jaundi...
# 7   hypertension, proteinuria, umbilical cord vasc...
# 8   injury, device breakage, uterine perforation, ...
# 9   hypertension, renal failure chronic, condition...
# 10          premature baby, apgar score low, acidosis
# 11                                   pulmonary oedema
# 12                                   pulmonary oedema
# 13                                   pulmonary oedema
# 14                                   pulmonary oedema
# 15                abortion spontaneous, off label use
# 16               oligohydramnios, breech presentation
# 17                                         thrombosis
# 18
# 19                                    oligohydramnios
# 20          meconium stain, amniotic cavity infection
# 21           abortion late, amniotic cavity infection
# 22  intraventricular haemorrhage neonatal, low bir...
# 23          meconium stain, amniotic cavity infection
# 24                     pyelonephritis, normal newborn
# 25             angioedema, enlarged uvula, live birth
# 26                                injection site pain
# 27                                 infusion site pain
# 28       burning sensation, infusion related reaction
# 29  double outlet right ventricle, pulmonary arter...
# 30                anaemia, toxicity to various agents
# 31                                        anencephaly
# 32  congenital anomaly, meningomyelocele, talipes,...
# 33          vaginal haemorrhage, abdominal pain lower
# 34  patent ductus arteriosus, tricuspid valve inco...
# 35  dialysis, blood pressure inadequately controll...
# 36  acute hepatic failure, renal failure acute, re...
# 37  premature baby, acute hepatic failure, renal f...
# 39                                       micrognathia
# 40  wrong technique in drug usage process, abortio...
# 41               alcohol abuse, intentional underdose
# 42                  drug withdrawal syndrome neonatal
# 43                                 selective abortion
# 44                  drug withdrawal syndrome neonatal

# %% [markdown]
# ## Download and display final data

# %%
# Save the final DataFrame to a CSV file
final_file_path = 'final_pregnancy_drug_data.csv'
df.to_csv(final_file_path, index=False)

# Display the final DataFrame
display(df)

# Provide a download link for the CSV file 
from IPython.display import FileLink
FileLink(final_file_path)
# Out:
#    report_id patient_age patient_sex patient_weight  \
# 0   10009044           1           1              4
# 1   10016807        None           0           None
# 2   10019262        None           2           2.54
# 3   10023714          35           2             68
# 4   10038823           0           2            3.6
# 5   10017067        None           2         108.96
# 6   10027891        None           1           None
# 7   10027954          33           2           None
# 8   10047438          39           2           None
# 9   10051068          28           2           None
# 10  10056773        None           2           None
# 11  10056780        None           2           None
# 12  10056787        None           2           None
# 13  10056791        None           2           None
# 14  10056792        None           2           None
# 15  10060198        None           2           None
# 16  10072649          32           2           None
# 17  10144772          42           2             61
# 18  10227619          32           2           None
# 19  10235084          32           2           None
# 20  10003326          29           2           None
# 21  10003424          30           2           None
# 22  10003428        None           2           None
# 23  10003429          28           2           None
# 24  10003449          32           2           None
# 25  10222287          19           2           None
# 26  10285328          24           2           None
# 27  10287488          24           2           None
# 28  10396427          18           2           None
# 29  10440328           1           1            2.5
# 30  10014483           8        None           None
# 31  10056932        None           1           None
# 32  10059489        None           1            2.6
# 33  10074379          23           2           None
# 34  10079120        None           2            3.2
# 35  10012150          39           2           None
# 36  10012151           0           2             .8
# 37  10012212        None           2           None
# 39  10023077        None           0           None
# 40  10010087          28           2           None
# 41  10010162          33           2           None
# 42  10012752           4           2           None
# 43  10024207          30           2           None
# 44  10024410        None           1           None
#
#                                       drug_indication  \
# 0   HYPERTENSION, HYPERTENSION, GESTATIONAL DIABET...
# 1
# 2                                GESTATIONAL DIABETES
# 3                                   DIABETES MELLITUS
# 4   HIV INFECTION, HIV INFECTION, DIABETES MELLITU...
# 5   RENAL TRANSPLANT, RENAL TRANSPLANT, RENAL TRAN...
# 6
# 7                         PRE-ECLAMPSIA, HYPERTENSION
# 8                                       CONTRACEPTION
# 9   LABOUR INDUCTION, ASTHMA, ASTHMA, GESTATIONAL ...
# 10
# 11  THREATENED LABOUR, THREATENED LABOUR, THREATEN...
# 12  THREATENED LABOUR, THREATENED LABOUR, THREATEN...
# 13  THREATENED LABOUR, THREATENED LABOUR, THREATEN...
# 14  THREATENED LABOUR, THREATENED LABOUR, THREATEN...
# 15  INTRAPARTUM HAEMORRHAGE, POLYCYSTIC OVARIES, H...
# 16
# 17           PULMONARY EMBOLISM, PREGNANCY, PREGNANCY
# 18                             ASSISTED FERTILISATION
# 19
# 20                           LISTERIOSIS, LISTERIOSIS
# 21                           LISTERIOSIS, LISTERIOSIS
# 22
# 23              LISTERIOSIS, LISTERIOSIS, LISTERIOSIS
# 24  LISTERIOSIS, LISTERIOSIS, LISTERIOSIS, LISTERI...
# 25  PRODUCT USED FOR UNKNOWN INDICATION, PRODUCT U...
# 26                        STREPTOCOCCUS TEST POSITIVE
# 27                        STREPTOCOCCUS TEST POSITIVE
# 28                        STREPTOCOCCUS TEST POSITIVE
# 29  PRODUCT USED FOR UNKNOWN INDICATION, PRODUCT U...
# 30  HIV infection, Product used for unknown indica...
# 31
# 32       POSTPARTUM DEPRESSION, POSTPARTUM DEPRESSION
# 33                      TYPHOID FEVER, SEPSIS, SEPSIS
# 34                DEPRESSION, MINERAL SUPPLEMENTATION
# 35        HIV INFECTION, HIV INFECTION, HIV INFECTION
# 36        HIV INFECTION, HIV INFECTION, HIV INFECTION
# 37  MATERNAL EXPOSURE TIMING UNSPECIFIED, MATERNAL...
# 39  PRODUCT USED FOR UNKNOWN INDICATION, PRODUCT U...
# 40               DRUG DEPENDENCE, NICOTINE DEPENDENCE
# 41  DRUG DEPENDENCE, PRODUCT USED FOR UNKNOWN INDI...
# 42               DRUG DEPENDENCE, NICOTINE DEPENDENCE
# 43                   DRUG DEPENDENCE, DRUG DEPENDENCE
# 44  DRUG DEPENDENCE, DRUG DEPENDENCE, PRODUCT USED...
#
#    seriousness_congenital_anomaly  \
# 0                               1
# 1                            None
# 2                               1
# 3                            None
# 4                               1
# 5                            None
# 6                            None
# 7                            None
# 8                            None
# 9                            None
# 10                           None
# 11                           None
# 12                           None
# 13                           None
# 14                           None
# 15                           None
# 16                           None
# 17                           None
# 18                           None
# 19                           None
# 20                           None
# 21                           None
# 22                           None
# 23                           None
# 24                           None
# 25                           None
# 26                           None
# 27                           None
# 28                           None
# 29                              1
# 30                              2
# 31                              1
# 32                              1
# 33                           None
# 34                              1
# 35                           None
# 36                           None
# 37                              1
# 39                              1
# 40                           None
# 41                           None
# 42                           None
# 43                           None
# 44                           None
#
#                              target_medicinal_product  \
# 0                                             insulin
# 1                                             insulin
# 2                                             insulin
# 3                                    insulin glargine
# 4                                             insulin
# 5                                           labetalol
# 6                                labetalol, labetalol
# 7                                           labetalol
# 8                                           labetalol
# 9                                           labetalol
# 10                                  magnesium sulfate
# 11                                 magnesium sulfate.
# 12                                 magnesium sulfate.
# 13                                 magnesium sulfate.
# 14                                 magnesium sulfate.
# 15                                      progesterone.
# 16                                       progesterone
# 17                                       progesterone
# 18                                       progesterone
# 19                            progesterone (solution)
# 20                                        ceftriaxone
# 21                                        ceftriaxone
# 22                                        ceftriaxone
# 23                                        ceftriaxone
# 24                                        ceftriaxone
# 25                                       penicillin g
# 26                   penicillin g potassium injection
# 27                   penicillin g potassium injection
# 28  penicillin g potassium injection, penicillin g...
# 29                                       penicillin g
# 30  azithromycin, azithromycin, lamivudine, lamivu...
# 31                                       azithromycin
# 32                                       azithromycin
# 33                ceftriaxone injection, azithromycin
# 34                                       azithromycin
# 35                                     lamivudine-hiv
# 36                                     lamivudine-hiv
# 37                                         lamivudine
# 39                          lamivudine and zidovudine
# 40                                           nicotine
# 41                                           nicotine
# 42                                    nicotine (none)
# 43                                           nicotine
# 44                                           nicotine
#
#                               other_medicinal_product  \
# 0   metoprolol (unknown), bisoprolol, folio, dopeg...
# 1   hydralazine, methyldopa, telmisartan, amlodipi...
# 2                        effexor, zyprexa, levothyrox
# 3                                   solostar, humalog
# 4   combivir, kaletra, metformin, nexium, prenatal...
# 5   mycophenolate mofetil, calcitriol, azathioprin...
# 6                              nifedipine, nifedipine
# 7                              nifedipine, nifedipine
# 8   hydrochlorothiazide., triamcinolone, tylenol, ...
# 9   oxytocin, salbutamol, fluticasone, calcium, fe...
# 10                   heparin, ritodrine hydrochloride
# 11                             uteron, betamethasone.
# 12                     uteron, betamethasone., uteron
# 13                     uteron, uteron, betamethasone.
# 14                     uteron, uteron, betamethasone.
# 15          glucophage, eltroxin, glucophage, clexane
# 16  armour thyroid, procardia, lovenox, aspirin, c...
# 17                     lovenox, estradiol, folic acid
# 18                    bravelle, decapeptyl /00957902/
# 19  acetylsalicylic acid({=100 mg), procardia, lov...
# 20                                      metronidazole
# 21                                      metronidazole
# 22                         metronidazole, amoxicillin
# 23                         metronidazole, amoxicillin
# 24  clarithromycin, amoxicillin+clavulanate, cefme...
# 25  ranitidine, entonox, paracetamol, piriton, lev...
# 26                                                usp
# 27                                                usp
# 28                                           usp, usp
# 29  augmentin, effexor, venlafaxine hydrochloride ...
# 30  isentress, isentress, isentress, abacavir, aba...
# 31  effexor, amox-clav, effexor, venlafaxine hcl, ...
# 32  venlafaxine, nitrofur mac, metronidazole., zan...
# 33                           usp (in dextrose), zosyn
# 34  wellbutrin, wellbutrin xl, clarinex, naproxen....
# 35                                  abacavir, kaletra
# 36                                  abacavir, kaletra
# 37                                  kaletra, abacavir
# 39       prezista, lexiva, zidovudine, norvir, viread
# 40                              buprenorphine generic
# 41  suboxone film, alcohol, prenatal vitamins, zol...
# 42                                      suboxone 8 mg
# 43                   suboxone, subutex 8 mg, vitamins
# 44  suboxone 8 mg, buprenorphine 8 mg (none), unsp...
#
#                              pregnancy_reaction_event  \
# 0                    foetal exposure during pregnancy
# 1   foetal death, foetal heart rate deceleration a...
# 2                    foetal exposure during pregnancy
# 3        ectopic pregnancy, exposure during pregnancy
# 4                    foetal exposure during pregnancy
# 5    maternal exposure during pregnancy, foetal death
# 6                    foetal exposure during pregnancy
# 7       premature delivery, exposure during pregnancy
# 8   premature delivery, pregnancy with contracepti...
# 9                  maternal exposure during pregnancy
# 10                   foetal exposure during pregnancy
# 11                 maternal exposure during pregnancy
# 12                 maternal exposure during pregnancy
# 13                 maternal exposure during pregnancy
# 14                 maternal exposure during pregnancy
# 15                 maternal exposure during pregnancy
# 16  foetal growth restriction, exposure during pre...
# 17                          exposure during pregnancy
# 18                                  ectopic pregnancy
# 19                          exposure during pregnancy
# 20                 maternal exposure during pregnancy
# 21   foetal death, maternal exposure during pregnancy
# 22  foetal distress syndrome, foetal exposure duri...
# 23                 maternal exposure during pregnancy
# 24                 maternal exposure during pregnancy
# 25                          exposure during pregnancy
# 26                          exposure during pregnancy
# 27                          exposure during pregnancy
# 28                          exposure during pregnancy
# 29                   foetal exposure during pregnancy
# 30                   foetal exposure during pregnancy
# 31                 maternal exposure during pregnancy
# 32                 maternal exposure during pregnancy
# 33            exposure during pregnancy, foetal death
# 34  maternal exposure during pregnancy, persistent...
# 35      premature delivery, exposure during pregnancy
# 36                   foetal exposure during pregnancy
# 37  foetal growth restriction, foetal exposure dur...
# 39                   foetal exposure during pregnancy
# 40                 maternal exposure during pregnancy
# 41                 maternal exposure during pregnancy
# 42                   foetal exposure during pregnancy
# 43                          exposure during pregnancy
# 44                   foetal exposure during pregnancy
#
#                                  other_reaction_event
# 0        congenital hydronephrosis, ureteric stenosis
# 1                                      premature baby
# 2                   multiple congenital abnormalities
# 3                             no therapeutic response
# 4   ventricular septal defect, atrial septal defec...
# 5
# 6   neonatal respiratory distress syndrome, jaundi...
# 7   hypertension, proteinuria, umbilical cord vasc...
# 8   injury, device breakage, uterine perforation, ...
# 9   hypertension, renal failure chronic, condition...
# 10          premature baby, apgar score low, acidosis
# 11                                   pulmonary oedema
# 12                                   pulmonary oedema
# 13                                   pulmonary oedema
# 14                                   pulmonary oedema
# 15                abortion spontaneous, off label use
# 16               oligohydramnios, breech presentation
# 17                                         thrombosis
# 18
# 19                                    oligohydramnios
# 20          meconium stain, amniotic cavity infection
# 21           abortion late, amniotic cavity infection
# 22  intraventricular haemorrhage neonatal, low bir...
# 23          meconium stain, amniotic cavity infection
# 24                     pyelonephritis, normal newborn
# 25             angioedema, enlarged uvula, live birth
# 26                                injection site pain
# 27                                 infusion site pain
# 28       burning sensation, infusion related reaction
# 29  double outlet right ventricle, pulmonary arter...
# 30                anaemia, toxicity to various agents
# 31                                        anencephaly
# 32  congenital anomaly, meningomyelocele, talipes,...
# 33          vaginal haemorrhage, abdominal pain lower
# 34  patent ductus arteriosus, tricuspid valve inco...
# 35  dialysis, blood pressure inadequately controll...
# 36  acute hepatic failure, renal failure acute, re...
# 37  premature baby, acute hepatic failure, renal f...
# 39                                       micrognathia
# 40  wrong technique in drug usage process, abortio...
# 41               alcohol abuse, intentional underdose
# 42                  drug withdrawal syndrome neonatal
# 43                                 selective abortion
# 44                  drug withdrawal syndrome neonatal
# C:\Users\samue\Data Preparation\final_pregnancy_drug_data.csv

# %% [markdown]
# ## Ethical Considertions of Data Wrangling

# %% [markdown]
# The changess made included handling missing values, removing duplicates, as well as creating and removing columns.  These steps improve data consistency and readability, however could impact the analysis's integridy by excluding or altering original data.  The source of the data is regulated by the FDA, which specifies privacy guidlines to protect patient confidentialiity. Data analysis must comply with FDA terms since the information gathered is senstive health-related data.  The FDA also advises caution to the open API, since the data ins unvalidated.  Ethical considerations and documentation of each transformation step in the data wrangling process were performed to ensure transparancy to the potential data loss or introduction of incomplete or biased results.
